# %% [markdown]
# <div dir="rtl">
#
# # ویرایش تصاویر (Manipulating Images)
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# <h2>اهداف (Objectives)</h2>
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# در این آزمایشگاه (Lab)، یاد خواهید گرفت که چگونه تصاویر و آرایه‌های تصویر (Image Arrays) OpenCV را ویرایش کنید. یاد خواهید گرفت که چگونه یک تصویر را کپی کنید تا از نام‌گذاری مشترک (Aliasing) جلوگیری شود. ما چرخاندن (Flipping) تصاویر و برش (Cropping) تصاویر را پوشش خواهیم داد. همچنین یاد خواهید گرفت که پیکسل‌های تصویر را تغییر دهید؛ این به شما امکان می‌دهد شکل‌ها (Shapes) رسم کنید، متن (Text) بنویسید و تصاویر را روی تصاویر دیگر قرار دهید (Superimpose).
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# <ul>
#     <li><a href='https://#MI'>ویرایش تصاویر (Manipulating Images) </a>
#         <ul>
#             <li>کپی کردن تصاویر (Copying Images)  </li>
#             <li>چرخاندن تصاویر (Flipping Images) </li>
#             <li>برش یک تصویر (Cropping an Image) </li>
#             <li>تغییر پیکسل‌های خاص تصویر (Changing Specific Image Pixels) </li>
#         </ul>
#     </li>
# </ul>
#
# </div>

# %% [markdown]
# ***

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۱: نصب کتابخانه‌های مورد نیاز (Required Libraries)
#
# </div>

# %%
# دستور نصب کتابخانه‌ها را اینجا بنویسید
# !pip install opencv-python-headless matplotlib pillow numpy

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۲: دانلود تصاویر ورودی از گیت‌هاب
#
# تمام تصاویر ورودی مورد نیاز برای این آزمایشگاه (Lab) از مخزن گیت‌هاب دانلود می‌شوند:
#
# </div>

# %%
# کد دانلود تصاویر را اینجا بنویسید
# از urllib.request.urlretrieve استفاده کنید
# آدرس: https://raw.githubusercontent.com/amira133/cv-course-summer-2026/main/images
# تصاویر: cat.png, lenna.png, baboon.png, im1.jpg, im3.jpg, im5.jpg, im6.jpg

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۳: import کردن کتابخانه‌ها
#
# ما از این توابع import شده در این آزمایشگاه استفاده خواهیم کرد:
#
# </div>

# %%
# import کردن کتابخانه‌های لازم را اینجا بنویسید
# matplotlib.pyplot, cv2, numpy, os

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۴: کپی کردن تصاویر (Copying Images)
#
# اگر می‌خواهید یک آرایه (Array) را به متغیر دیگری نسبت دهید، باید از متد (Method) `copy` استفاده کنید. اگر متد `copy()` را اعمال نکنیم، متغیر به همان مکان در حافظه (Memory) اشاره خواهد کرد. آرایه زیر را در نظر بگیرید:
#
# </div>

# %%
# کد بارگذاری و رسم تصویر im1.jpg را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# اگر متد `copy()` را اعمال نکنیم، متغیر جدید به همان مکان در حافظه (Memory) اشاره خواهد کرد:
#
# </div>

# %%
# کد کپی کردن آرایه تصویر به A بدون copy() را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# ما از تابع `id` برای پیدا کردن آدرس حافظه (Memory Address) شیء استفاده می‌کنیم؛ می‌بینیم که همان آدرس آرایه اصلی است:
#
# </div>

# %%
# کد مقایسه آدرس حافظه A و image را اینجا بنویسید

# %%
# کد بررسی آدرس حافظه image را اینجا بنویسید

# %%
# کد بررسی آدرس حافظه A را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# اگر متد `copy()` را اعمال کنیم، آدرس حافظه (Memory Address) متفاوت است:
#
# </div>

# %%
# کد کپی کردن آرایه تصویر به B با copy() و مقایسه آدرس را اینجا بنویسید

# %%
# کد بررسی آدرس حافظه image را اینجا بنویسید

# %%
# کد بررسی آدرس حافظه B را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# وقتی متد `copy()` را اعمال نکنیم، متغیر به همان مکان در حافظه (Memory) اشاره خواهد کرد. آرایه `image` را در نظر بگیرید؛ اگر همه مقادیر آن را صفر کنیم، تمام مقادیر `A` نیز صفر خواهد شد. این به این دلیل است که `image` و `A` به همان مکان در حافظه اشاره می‌کنند، اما `B` تحت تأثیر قرار نخواهد گرفت.
#
# </div>

# %%
# کد صفر کردن همه پیکسل‌های image را اینجا بنویسید

# %%
# کد رسم مقایسه‌ای image و A را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# می‌بینیم که آن‌ها یکسان هستند؛ به این حالت نام‌گذاری مشترک (Aliasing) گفته می‌شود. نام‌گذاری مشترک هر زمان رخ می‌دهد که مقدار یک متغیر به متغیر دیگری نسبت داده شود، زیرا متغیرها فقط نام‌هایی هستند که ارجاع به مقادیر را ذخیره می‌کنند. همچنین می‌توانیم `image` و آرایه `B` را مقایسه کنیم:
#
# </div>

# %%
# کد رسم مقایسه‌ای image و B را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# آن‌ها متفاوت هستند، زیرا از متد `copy` استفاده شده است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۵: چرخاندن تصاویر (Flipping Images)
#
# چرخاندن تصاویر شامل مرتب‌سازی مجدد ایندکس پیکسل‌ها است به طوری که جهت‌گیری (Orientation) تصویر تغییر کند. تصویر زیر را در نظر بگیرید:
#
# </div>

# %%
# کد بارگذاری و رسم تصویر im3.jpg را اینجا بنویسید

# %%
# کد دریافت ابعاد تصویر با shape را اینجا بنویسید

# %%
# کد باز کردن shape و چاپ ارتفاع، عرض و کانال‌ها را اینجا بنویسید

# %%
# کد دسترسی به ابعاد با ایندکس و چاپ را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# بیایید تصویر را به صورت عمودی بچرخانیم. ابتدا، یک آرایه با اندازه مساوی از نوع تصویر بیتی <code>np.uint8</code> ایجاد می‌کنیم:
#
# </div>

# %%
# کد ایجاد آرایه خالی array_flip را اینجا بنویسید

# %%
# کد بررسی ابعاد array_flip را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# ما اولین ردیف پیکسل‌های آرایه اصلی را به آخرین ردیف آرایه جدید اختصاص می‌دهیم. این فرآیند را برای هر ردیف تکرار می‌کنیم، شماره ردیف آرایه اصلی را افزایش و ایندکس ردیف آرایه جدید را کاهش می‌دهیم و پیکسل‌ها را بر این اساس اختصاص می‌دهیم:
#
# </div>

# %%
# کد چرخاندن عمودی با حلقه را اینجا بنویسید

# %%
# کد بررسی ابعاد array_flip بعد از چرخاندن را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# نتایج را رسم می‌کنیم:
#
# </div>

# %%
# کد رسم array_flip را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# <code>OpenCV</code> چندین روش برای چرخاندن تصویر دارد؛ می‌توانیم از تابع <code>flip()</code> استفاده کنیم؛ آرایه تصویر ورودی را داریم. پارامتر <code>flipCode</code> مقداری است که نشان می‌دهد چه نوع چرخشی می‌خواهیم انجام دهیم:
#
# <li><code>flipcode</code> = 0: چرخش عمودی حول محور x</li>
# <li><code>flipcode</code> > 0: چرخش افقی حول محور y (مقدار مثبت)</li>
# <li><code>flipcode</code> < 0: چرخش عمودی و افقی، چرخش حول هر دو محور (مقدار منفی)</li>
#
# بیایید <code>flipcode</code>های مختلف را در یک حلقه اعمال کنیم:
#
# </div>

# %%
# کد حلقه flipcode های 0, 1, -1 را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# همچنین می‌توانیم از تابع <code>rotate()</code> استفاده کنیم. پارامتر یک عدد صحیح است که نشان می‌دهد چه نوع چرخشی می‌خواهیم انجام دهیم:
#
# </div>

# %%
# کد چرخاندن با rotate را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# ماژول OpenCV ویژگی‌های داخلی دارد که نوع چرخش را توصیف می‌کنند؛ مقادیر فقط اعداد صحیح هستند. چند مورد در <code>dict</code> زیر نشان داده شده است:
#
# </div>

# %%
# کد ساخت دیکشنری flip را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# می‌بینیم که مقادیر فقط اعداد صحیح هستند:
#
# </div>

# %%
# کد نمایش ROTATE_90_CLOCKWISE را اینجا بنویسید

# %%
# کد نمایش ROTATE_90_COUNTERCLOCKWISE را اینجا بنویسید

# %%
# کد نمایش ROTATE_180 را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# می‌توانیم هر یک از خروجی‌ها را با استفاده از مقادیر مختلف پارامتر رسم کنیم:
#
# </div>

# %%
# کد رسم مقایسه‌ای چرخش‌های مختلف را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۶: برش یک تصویر (Cropping an Image)
#
# برش به معنای «بریدن» بخشی از تصویر و دور انداختن بقیه است؛ می‌توانیم با استفاده از آرایه‌ها برش دهیم.
# بیایید با یک برش عمودی شروع کنیم؛ متغیر <code>upper</code> اولین ردیفی است که می‌خواهیم در تصویر قرار دهیم و متغیر <code>lower</code> آخرین ردیفی است که می‌خواهیم قرار دهیم. سپس از برش (Slicing) برای به دست آوردن تصویر جدید استفاده می‌کنیم:
#
# </div>

# %%
# کد بارگذاری و رسم تصویر im6.jpg را اینجا بنویسید

# %%
# کد برش عمودی با upper و lower و رسم را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# آرایه <code>crop_vertical</code> را در نظر بگیرید؛ همچنین می‌توانیم به صورت افقی برش دهیم. متغیر <code>left</code> اولین ستونی است که می‌خواهیم در تصویر قرار دهیم و متغیر <code>right</code> آخرین ستونی است که می‌خواهیم در تصویر قرار دهیم:
#
# </div>

# %%
# کد برش افقی با left و right و رسم را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۷: تغییر پیکسل‌های خاص تصویر (Changing Specific Image Pixels)
#
# می‌توانیم پیکسل‌های خاص تصویر را با استفاده از نمایه‌گذاری (Indexing) آرایه تغییر دهیم؛ برای مثال، می‌توانیم همه کانال‌های ناحیه‌ای که برش زدیم را صفر کنیم:
#
# </div>

# %%
# کد صفر کردن ناحیه برش‌خورده را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# می‌توانیم نتایج را با تصویر جدید مقایسه کنیم:
#
# </div>

# %%
# کد رسم مقایسه‌ای تصویر اصلی و تغییر یافته را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# همچنین می‌توانیم شکل‌ها (Shapes) ایجاد کنیم و در <code>OpenCV</code> می‌توانیم از متد <code>rectangle</code> استفاده کنیم. پارامتر <code>pt1</code> مختصات بالا-چپ مستطیل است: <code>(left,top)</code> یا $(x\_0,y\_0)$، <code>pt2</code> مختصات پایین-راست <code>(right,lower)</code> یا $(x\_1,y\_1)$ است. پارامتر <code>color</code> یک تاپل (Tuple) است که شدت هر کانال <code>(blue, green, red)</code> را نشان می‌دهد. در نهایت، ضخامت خط (Line Thickness) را داریم:
#
# </div>

# %%
# کد رسم مستطیل با rectangle را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# می‌توانیم متن (Text) را روی یک تصویر با استفاده از تابع <code>putText</code> با مقادیر پارامتر زیر قرار دهیم:
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# <li><code>img</code>: آرایه تصویر</li>
# <li><code>text</code>: رشته متنی که قرار است روی تصویر قرار گیرد</li>
# <li><code>org</code>: گوشه پایین-چپ رشته متنی در تصویر</li>
# <li><code>fontFace</code>: نوع فونت</li>
# <li><code>fontScale</code>: مقیاس فونت</li>
# <li><code>color</code>: رنگ متن</li>
# <li><code>thickness</code>: ضخامت خطوط استفاده‌شده برای رسم متن</li>
# <li><code>lineType</code>: نوع خط</li>
#
# </div>

# %%
# کد قرار دادن متن با putText را اینجا بنویسید

# %% [markdown]
# <div dir="rtl">
#
# ## گام ۸: سوال ۲ (Question 2)
#
# از تصویر `baboon.png` این آزمایشگاه استفاده کنید یا هر تصویری که دوست دارید بردارید.
#
# تصویر را باز کنید و یک شیء تصویر OpenCV به نام `im` ایجاد کنید، تصویر را از قالب BGR به قالب RGB تبدیل کنید، `im` را به صورت عمودی حول محور x بچرخانید و تصویری به نام `im_flip` ایجاد کنید، `im` را با چرخاندن افقی حول محور y آینه کنید و تصویری به نام `im_mirror` ایجاد کنید، در نهایت هر دو تصویر را رسم کنید.
#
# </div>

# %%
# راه‌حل سوال ۲ را اینجا بنویسید
